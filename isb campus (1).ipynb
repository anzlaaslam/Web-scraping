# %%
import requests
# to scrap data

# %%
from bs4 import BeautifulSoup
# to extract html content

# %%
html_file_path = 'FAST NUCES Islamabad.html'

# %%
html_file_path
# Out:
# 'FAST NUCES Islamabad.html'

# %%
try:
    # Open the HTML file for reading
    with open(html_file_path, 'r', encoding='utf-8') as file:
        # Read the content of the HTML file
        html_content = file.read()

    # Now you have the HTML content in the 'html_content' variable
    print(html_content)
except FileNotFoundError:
    print(f"File '{html_file_path}' not found.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <link href="https://fonts.googleapis.com/css?family=Tangerine" rel="stylesheet" />
#     <link rel="icon" href="/assets/Images/logo.png" type="image/x-icon" />
#     <link rel="shortcut icon" type="image/x-icon" href="/assets/Images/logo.png" />
#     <title>FAST NUCES Islamabad</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link href="/assets/css/assets?v=8x48N6TWkg4FUExQXS0jRuRAI4Sh6pTATFY2WpFX5As1" rel="stylesheet"/>
#
#     <link href="/assets/css/typography?v=W-aGnSsghynCeOpBMLSUYIaQvAzd9CVQRh0KnxwGQyU1" rel="stylesheet"/>
#
#     <link rel="stylesheet" type="text/css" href="/assets/css/shortcodes/shortcodes.css">
#
#     <link rel="stylesheet" type="text/css" href="/assets/css/style12.css">
#     <link class="skin" rel="stylesheet" type="text/css" href="/assets/css/color/color-1.css">
# ...

# %%
URL = "http://isb.nu.edu.pk/Faculty/allfaculty"
r = requests.get(URL)
print(r)
# returns no of requests
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup (r.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://fonts.googleapis.com/css?family=Tangerine" rel="stylesheet"/>
# <link href="/assets/Images/logo.png" rel="icon" type="image/x-icon"/>
# <link href="/assets/Images/logo.png" rel="shortcut icon" type="image/x-icon"/>
# <title>FAST NUCES Islamabad</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/assets/css/assets?v=8x48N6TWkg4FUExQXS0jRuRAI4Sh6pTATFY2WpFX5As1" rel="stylesheet"/>
# <link href="/assets/css/typography?v=W-aGnSsghynCeOpBMLSUYIaQvAzd9CVQRh0KnxwGQyU1" rel="stylesheet"/>
# <link href="/assets/css/shortcodes/shortcodes.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/style12.css" rel="stylesheet" type="text/css"/>
# <link class="skin" href="/assets/css/color/color-1.css" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://fonts.googleapis.com/css?family=Tangerine" rel="stylesheet"/>
# <link href="/assets/Images/logo.png" rel="icon" type="image/x-icon"/>
# <link href="/assets/Images/logo.png" rel="shortcut icon" type="image/x-icon"/>
# <title>FAST NUCES Islamabad</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/assets/css/assets?v=8x48N6TWkg4FUExQXS0jRuRAI4Sh6pTATFY2WpFX5As1" rel="stylesheet"/>
# <link href="/assets/css/typography?v=W-aGnSsghynCeOpBMLSUYIaQvAzd9CVQRh0KnxwGQyU1" rel="stylesheet"/>
# <link href="/assets/css/shortcodes/shortcodes.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/style12.css" rel="stylesheet" type="text/css"/>
# <link class="skin" href="/assets/css/color/color-1.css" rel="stylesheet" type="text/css"/>
# ...

# %%
img = soup.findAll('div', class_='menu-logo')
img
# Out:
# [<div class="menu-logo">
#  <a href="/"><img alt="" src="/assets/images/logo.png"/></a>
#  </div>,
#  <div class="menu-logo">
#  <a href="/"><img alt="" src="/assets/Images/NU-logo.jpg"/></a>
#  </div>]
